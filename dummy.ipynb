# %%
import pandas as pd
df = pd.read_csv('policecalls2024.csv')
df.shape
# Out:
# (392079, 15)

# %%
import requests

url = "https://grocery-pricing-api.p.rapidapi.com/searchGrocery"

querystring = {"keyword":"sweet potato","perPage":"10","page":"1"}

headers = {
	"X-RapidAPI-Key": "5847527b5bmshe2f2f4e69370c30p1a3ec9jsn659fda58c155",
	"X-RapidAPI-Host": "grocery-pricing-api.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'hits': [{'id': '0WPN6BLFII9C', 'name': 'Sweet Potatoes Whole Fresh, Each (Batata Mameya)', 'shortDescription': 'Sweet Potatoes Whole Fresh, Each (Batata Mameya)', 'priceInfo': {'itemPrice': '$2.05', 'linePrice': '$1.02', 'linePriceDisplay': 'Now $1.02', 'savings': 'SAVE $1.03', 'savingsAmt': 1.03, 'wasPrice': '$2.05', 'unitPrice': '$1.00/lb', 'shipPrice': '', 'minPrice': 0, 'minPriceForVariant': '', 'priceRangeString': '', 'subscriptionPrice': '', 'subscriptionString': '', 'priceDisplayCondition': 'each', 'finalCostByWeight': True, 'submapType': '', 'eaPricingText': '', 'eaPricingPreText': '', 'memberPriceString': '', 'subscriptionDualPrice': None, 'subscriptionPercentage': None, 'isB2BPrice': False}, 'image': 'https://i5.walmartimages.com/asr/1696f72c-2214-4f16-9a53-f737b4039260.5059dac4fe3ac4097e944e7e59ac55b9.jpeg?odnHeight=180&odnWidth=180&odnBg=ffffff', 'objectID': '5f36cbae50929_dashboard_generated_id', '_highlightResult': {'id': {'value': '0WPN6BLFII9C', 'matchLevel': 'none'
# ...
